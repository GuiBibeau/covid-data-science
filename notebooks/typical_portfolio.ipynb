# %%
# add sys path to load src
import sys
sys.path.append('../')

# %%
# libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import data functions
from src import make_datasets

# load dataframe
df = make_datasets.make_portfolio_df()

# save cleaned data
df.to_csv('../data/processed/portfolio.csv')

# plot
# sns.set_palette("tab10")
ax = sns.barplot(data=df, x='REF_DATE', y='value', hue='Assets and debts')
ax.set(xlabel='Year', ylabel='Value in $CAD')
plt.style.use('dark_background')
plt.legend( title='Asset Class', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small')
