# %%
import sys
sys.path.append('../')

# %%
import seaborn as sns
import pandas as pd
from src import make_datasets, merge_datasets

df = merge_datasets.merge_realestate_df(make_datasets.make_real_estate_df(), make_datasets.make_inflation_df())
df.to_csv('../data/processed/real_estate.csv')

sns.lineplot(x='Date', y='value', hue='variable', 
             data=pd.melt(df.rename(columns={'Composite_Benchmark_Change': 'Home Prices', 'Inflation_Change': 'Inflation'}), ['Date']))
